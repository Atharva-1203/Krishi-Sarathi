# %% [markdown]
# # Notebook 06: Model Evaluation Metrics
#
# ### 1. Objective
# Examine detailed performance evaluations of the champion ExtraTrees model, highlighting confusion matrices and probability calibration curves.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import ExtraTreesClassifier
import seaborn as sns

# Run eval on split
df = pd.read_csv(r'../ml/datasets/v3/dataset.csv')
X = df.drop(columns=['label'])
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

et = ExtraTreesClassifier(n_estimators=100, random_state=42)
et.fit(X_train_scaled, y_train)
y_pred = et.predict(X_test_scaled)

print(classification_report(y_test, y_pred))

# %%
# Compute and visualize Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, xticklabels=et.classes_, yticklabels=et.classes_, cmap="BuPu", annot=True, fmt='d')
plt.title("Validation Set Confusion Matrix")
plt.ylabel("True Crop")
plt.xlabel("Predicted Crop")
plt.show()
